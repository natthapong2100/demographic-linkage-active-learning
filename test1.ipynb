# %%
import pandas as pd

# Load the CSV file
file_path = 'linkage data/_1/clean/birth_records.csv'
data = pd.read_csv(file_path)

# Display the data
data.head()  # Display the first few rows of the dataset
# Out:
#      ID  family  marriage child's forname(s) child's surname  birth day  \
# 0  3020     656     656.0              Sarah           Novak         20
# 1  3022     664     664.0           Margaret            Soto         11
# 2  3024     725     725.0           Margaret           Szabo         23
# 3  3026     716     716.0           Isabella           Jones         15
# 4  3028     766     766.0              Agnes          Larsen          1
#
#   birth month  birth year                                      address sex  \
# 0     JANUARY        1855                  1 Muir Road, Welltree, Fife   F
# 1     OCTOBER        1855  106 Courthill Street, Dalry, North Ayrshire   F
# 2      AUGUST        1855             1 Langlands Bank, Wilton, Hawick   F
# 3     JANUARY        1855      1 St Margaret's Drive, West End, Hawick   F
# 4   SEPTEMBER        1855              1 Skua Drive, Dalgety Bay, Fife   F
#
#    ... FATHER_IDENTITY DEATH_RECORD_IDENTITY PARENT_MARRIAGE_RECORD_IDENTITY  \
# ...
